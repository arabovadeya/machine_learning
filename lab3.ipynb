# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 0. Провести первичный анализ данных. Предоставить следующую
# информацию о наборе данных:
# − описание набора данных, пояснения, позволяющие лучше понять
# природу данных.
# − описание каждого признака и его тип.
# − форма набора данных: количество элементов набора, количество
# признаков, количество пропущенных значений, среднее значение
# отдельных признаков, максимальные и минимальные значения
# отдельных признаков и прочие показатели.
# − наличие/отсутствие пустых значение; при наличие пустых
# значений, необходимо от них избавиться

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6243d39b-3ee6-463a-826f-2e788f160486" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6243d39b-3ee6-463a-826f-2e788f160486">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv(filepath_or_buffer = "titanic.csv",
                       sep = ',')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(data.describe())
print(data.info())
print(data.isnull().any())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# ...

# %%
print(data.dropna())
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 1. Найти количество наблюдений для каждого значения целевой
# переменной Survived и применить к полученным данным метод plot, чтобы
# построить столбчатую диаграмму.

# %%
s=data["Survived"].value_counts()
print(s)
s.plot(kind="bar")
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64
# <Axes: >

# %% [markdown]
# 2. Построить такую же диаграмму, используя логарифмический
# масштаб.

# %%
s.plot(kind="bar",log=True)
# Out:
# <Axes: >

# %% [markdown]
# 3. Построить две гистограммы по значениям признака Pclass - одну для
# выживших (Survived равен 1) и другую - нет (Survived равен 0).

# %%
sur=data[data["Survived"]==1]
dead=data[data["Survived"]==0]
sur.Pclass.hist()
# Out:
# <Axes: >

# %%
dead.Pclass.hist()
# Out:
# <Axes: >

# %% [markdown]
# 4. Подобрать значение аргумента density так, чтобы по вертикали
# графика было расположено не число наблюдений, а плотность распределения.
# Число бинов должно равняться 20 для обеих гистограмм, а коэффициент alpha
# равным 0.5, чтобы гистограммы были полупрозрачными и не загораживали
# друг друга. Создать легенду с двумя значениями: “ Survived 0” и “ Survived 1”.
# Гистограмма выживших должна быть серого цвета, а невыживших - красного.
# Название горизонтальной оси – “ Survived”.

# %%
plt.figure(figsize=(10, 5))
plt.hist(sur.Pclass, alpha=0.5, bins=20, density=True, label='Surived 1', color="gray")
plt.hist(dead.Pclass, alpha=0.5, bins=20, density=True, label='Survived 0', color="red")
plt.legend()
plt.xlabel("Survived")
# Out:
# Text(0.5, 0, 'Survived')

# %% [markdown]
# 5. Аналогично изобразить гистограмму выживаемости относительно
# пола пассажиров

# %%
plt.figure(figsize=(10, 5))
plt.hist(sur.Sex, alpha=0.5, bins=20, density=True, label='Surived 1', color="gray")
plt.hist(dead.Sex, alpha=0.5, bins=20, density=True, label='Survived 0', color="red")
plt.legend()
plt.xlabel("Survived")
# Out:
# Text(0.5, 0, 'Survived')

# %% [markdown]
# 6. Исследовать зависимость выживаемости пассажиров от количества
# родственников на борту (признак Parch). Построить график, показывающий
# процент выживших в зависимости от количества родственников

# %%
sur=[data[(data["Parch"] == i) & (data["Survived"] == 1)].Survived.count() for i in range(0,7)]
sur1=[data[(data["Parch"] == i)].Survived.count() for i in range(0,7)]
count=[0, 1, 2, 3, 4, 5, 6]
spct=[sur[i]/(sur1[i]/100) for i in range(0,7)]
print(spct)
print(sur)
print(sur1)
plt.plot(count, spct)
# Out:
# [34.365781710914455, 55.08474576271187, 50.0, 60.0, 0.0, 20.0, 0.0]
# [233, 65, 40, 3, 0, 1, 0]
# [678, 118, 80, 5, 4, 5, 1]

# %% [markdown]
# 7. Исследовать распределение стоимости билетов для пассажиров
# разных возрастных групп. Построить ящик с усами, где по горизонтальной оси
# будут возрастные группы, а по вертикальной - стоимость билетов.

# %%
data[['Age','Fare']].boxplot(by="Age")
# Out:
# <Axes: title={'center': 'Fare'}, xlabel='[Age]'>

# %% [markdown]
# 8. Определить процент выживших пассажиров по возрастным группам
# (например, 0-9 лет, 10-19 лет и т.д.) и отобразить результаты на круговой
# диаграмме.

# %%
groups=[data[(data["Age"] > (i-1)*10) & (data["Age"] < i*10-1) & (data["Survived"] == 1)].Survived.count() for i in range(1,9)]
gr1=[data[(data["Age"] > (i-1)*10) & (data["Age"] < i*10-1)].Survived.count() for i in range(1,9)]
pct1=[groups[i]/(gr1[i]/100) for i in range(0,8)]
indeces=["0-9","10-19","20-29","30-39","40-49","50-59","60-69","70-79"]
print(pct1)
# Out:
# [66.66666666666666, 42.666666666666664, 35.67567567567568, 45.3125, 34.285714285714285, 41.66666666666667, 26.666666666666668, 0.0]

# %%
plt.pie(x=pct1,labels=indeces)
# Out:
# ([<matplotlib.patches.Wedge at 0x7b80a84d9570>,
# ...
#  [Text(0.8306345571639068, 0.7211423108132824, '0-9'),
#   Text(-0.3425616149290034, 1.0452997369067083, '10-19'),
#   Text(-1.0070974249484952, 0.4424418342133914, '20-29'),
#   Text(-0.9882784299789186, -0.4830173338902073, '30-39'),
#   Text(-0.28550301003868905, -1.0623031729496286, '40-49'),
#   Text(0.5768157973110538, -0.9366341526831132, '50-59'),
#   Text(1.0553235176558975, -0.31030996291189683, '60-69'),
#   Text(1.1, -2.6942229581241775e-16, '70-79')])

# %% [markdown]
# 9. Получить следующие диаграммы

# %%
b_dict=dict()
for i in range (1,100):
    b_dict[i]=data[(data["Age"] > i)&(data["Age"] <= i+1)].Survived.mean()

plt.figure(figsize=(20, 5))
b=pd.Series(b_dict).dropna()
my_color=[(x/30.0, x/30.0, 0.05) for x in range(30)]
ax=b.plot(kind="bar",xlabel="Age",ylabel="mean(Survived)",width=0.8, color=my_color)
ax.grid(axis='y')

# %%
with_family=data[data['SibSp'] != 0]
alone=data[data['SibSp'] == 0]
xlabels=["With Family", "Alone"]
y1=[with_family.count(),alone.count()]
y2=[with_family.Survived.mean(),alone.Survived.mean()]
fig, (ax, ax1) = plt.subplots(1, 2)
plt.subplots_adjust(wspace=0.3)
ax.bar(xlabels[0],y1[0])
ax.bar(xlabels[1],y1[1], color='g')
ax.set_ylabel("counts")
ax.set_xlabel("Family")
ax1.bar(xlabels[0],y2[0])
ax1.bar(xlabels[1],y2[1], color='g')
ax1.set_ylabel("mean(Survived)")
ax1.set_xlabel("Family")
plt.show()
