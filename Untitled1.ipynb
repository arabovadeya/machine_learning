# %%
import pandas as pd

# %%
data = pd.read_csv("/content/math_students.csv")

# %%
data.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %%
data.tail(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# ...

# %%
len(data)
# Out:
# 395

# %%
len(data.columns)
# Out:
# 33

# %%
list(data)
# Out:
# ['school',
#  'sex',
#  'age',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Medu',
#  'Fedu',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'traveltime',
#  'studytime',
#  'failures',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences',
#  'G1',
#  'G2',
#  'G3']

# %%
pd.isnull(data).any()
# Out:
# school        False
# sex           False
# age           False
# address       False
# famsize       False
# Pstatus       False
# Medu          False
# Fedu          False
# Mjob          False
# Fjob          False
# reason        False
# guardian      False
# traveltime    False
# studytime     False
# failures      False
# schoolsup     False
# famsup        False
# paid          False
# activities    False
# nursery       False
# higher        False
# internet      False
# romantic      False
# famrel        False
# freetime      False
# goout         False
# Dalc          False
# Walc          False
# health        False
# absences      False
# G1            False
# G2            False
# G3            False
# dtype: bool

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
data['guardian'].value_counts()
# Out:
# mother    273
# father     90
# other      32
# Name: guardian, dtype: int64

# %%
data[(data['guardian']=='mother') & (data['Mjob']=='teacher') | (data['Mjob']=='at_home')]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 10      GP   F   15       U     GT3       T     4     4  teacher    health
# 13      GP   M   15       U     GT3       T     4     3  teacher     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 377     MS   F   18       R     LE3       T     4     4  teacher  services
# 379     MS   F   17       R     GT3       T     3     1  at_home     other
# 385     MS   F   18       R     GT3       T     2     2  at_home     other
# 386     MS   F   18       R     GT3       T     4     4  teacher   at_home
# 388     MS   F   18       U     LE3       T     3     1  teacher  services
#
# ...

# %%
data['alc'] = data['Dalc'] + data['Walc']
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 alc
# 0        3     4     1     1       3        6   5   6   6   2
# 1        3     3     1     1       3        4   5   5   6   2
# 2        3     2     2     3       3       10   7   8  10   5
# 3        2     2     1     1       5        2  15  14  15   2
# 4        3     2     1     2       5        4   6  10  10   3
#
# [5 rows x 34 columns]

# %%
len(data)
# Out:
# 395

# %%
len(data.columns)
# Out:
# 34

# %%
data.shape
# Out:
# (395, 34)

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'alc'],
#       dtype='object')

# %%
data['reason'].value_counts().idxmax()
# Out:
# 'course'

# %%
len(data[(data['Fedu']==0) & (data['Medu']==0)])
# Out:
# 0

# %%
age=data[data['school']=='MS']['age'].min()
data[(data['age'] == age) & (data['school']=='MS') ]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 351     MS   M   17       U     GT3       T     3     3    health     other
# 354     MS   M   17       R     GT3       T     4     3  services     other
# 356     MS   F   17       R     GT3       T     4     4   teacher  services
# 357     MS   F   17       U     LE3       A     3     2  services     other
# 363     MS   F   17       U     LE3       T     4     4   at_home   at_home
# 364     MS   F   17       R     GT3       T     1     2     other  services
# 367     MS   F   17       R     GT3       T     1     1     other  services
# 372     MS   F   17       U     GT3       T     2     2     other   at_home
# 373     MS   F   17       R     GT3       T     1     2     other     other
# 379     MS   F   17       R     GT3       T     3     1   at_home     other
# 382     MS   M   17       U     GT3       T     2     3     other  services
# ...

# %%
print("количество студентов, имеющих нечетное число пропусков",len(data[data['absences']%2!=0]))
data[data['absences']%2!=0]
# Out:
# количество студентов, имеющих нечетное число пропусков 41
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 37      GP   M   16       R     GT3       A     4     4     other   teacher
# 40      GP   F   16       U     LE3       T     2     2     other     other
# 206     GP   F   16       U     GT3       A     3     1  services     other
# 211     GP   M   17       U     LE3       T     4     4  services     other
# 213     GP   M   18       U     GT3       T     2     2  services     other
# 217     GP   M   18       U     LE3       T     3     3  services    health
# 218     GP   F   17       U     GT3       T     2     3   at_home     other
# 260     GP   F   18       U     GT3       T     4     3  services     other
# 262     GP   M   18       R     GT3       T     3     2     other     other
# 265     GP   M   18       R     LE3       A     3     4     other     other
# 270     GP   F   19       U     GT3       T     3     3     other  services
# ...

# %%
print("разность между средними итоговыми оценками студентов, состоящих и не состоящих в романтических отношениях.",round(data[data['romantic']=='yes']['G3'].mean()-data[data['romantic']=='no']['G3'].mean(),2))
data[data['romantic']=='yes']
data[data['romantic']=='no']
# Out:
# разность между средними итоговыми оценками студентов, состоящих и не состоящих в романтических отношениях. -1.26
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# ...

# %%
data['sex'].value_counts()
# Out:
# F    208
# M    187
# Name: sex, dtype: int64

# %%
print("количество студентов, чья опекуном является отец и который работает врачом(полицейским)",len(data[(data['guardian']=='father') & ((data['Fjob']=='health') | (data['Fjob']=='service'))]))
data[(data['guardian']=='father') & ((data['Fjob']=='health') | (data['Fjob']=='service'))]
# Out:
# количество студентов, чья опекуном является отец и который работает врачом(полицейским) 7
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob    Fjob  \
# 21      GP   M   15       U     GT3       T     4     4    health  health
# 52      GP   M   15       U     LE3       A     4     2    health  health
# 105     GP   F   15       U     GT3       A     3     3     other  health
# 122     GP   F   16       U     LE3       T     2     4     other  health
# 217     GP   M   18       U     LE3       T     3     3  services  health
# 278     GP   F   18       U     GT3       T     4     4    health  health
# 303     GP   F   17       U     GT3       T     3     2    health  health
#
#      ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 alc
# 21   ...        4     2     1     1       5        0  12  15  15   2
# 52   ...        5     5     3     4       5        6  11  11  10   7
# 105  ...        3     3     1     1       4       10  10  11  11   2
# ...

# %%
print("количество студентов, выбравших школу из-за репутации",len(data[data['reason']=='reputation']))
data[data['reason']=='reputation']
# Out:
# количество студентов, выбравших школу из-за репутации 105
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# 11      GP   F   15       U     GT3       T     2     1  services     other
# 16      GP   F   16       U     GT3       T     4     4  services  services
# 17      GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 357     MS   F   17       U     LE3       A     3     2  services     other
# 367     MS   F   17       R     GT3       T     1     1     other  services
# 374     MS   F   18       R     LE3       T     4     4     other     other
# 379     MS   F   17       R     GT3       T     3     1   at_home     other
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# ...

# %%
m=data['absences'].max()
data[data['absences']==m]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob      Fjob  ...  \
# 276     GP   F   18       R     GT3       A     3     2  other  services  ...
#
#     freetime goout  Dalc  Walc  health absences  G1 G2 G3 alc
# 276        1     1     1     1       5       75  10  9  9   2
#
# [1 rows x 34 columns]

# %%
print("Kоличество студентов, чьи родители имеют высшее образование",len(data[(data['Medu'] == 4) & (data['Fedu'] == 4)]))
data[(data['Medu'] == 4) & (data['Fedu'] == 4)]
# Out:
# Kоличество студентов, чьи родители имеют высшее образование 70
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 7       GP   F   17       U     GT3       A     4     4    other   teacher
# 10      GP   F   15       U     GT3       T     4     4  teacher    health
# 12      GP   M   15       U     LE3       T     4     4   health  services
# 15      GP   F   16       U     GT3       T     4     4   health     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 369     MS   F   18       R     GT3       T     4     4    other   teacher
# 374     MS   F   18       R     LE3       T     4     4    other     other
# 377     MS   F   18       R     LE3       T     4     4  teacher  services
# 380     MS   M   18       U     GT3       T     4     4  teacher   teacher
# 386     MS   F   18       R     GT3       T     4     4  teacher   at_home
#
# ...

# %%
m=data[data['absences'] > 5]['age'].max()
print(m)
data[(data['absences'] > 5) & (data['age'] == m)]
# Out:
# 22
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 247     GP   M   22       U     GT3       T     3     1  services  services
#
#      ... freetime goout  Dalc  Walc  health absences G1 G2 G3 alc
# 247  ...        4     5     5     5       1       16  6  8  8  10
#
# [1 rows x 34 columns]

# %%
print("разность между средними итоговыми оценками студентов, состоящих и не состоящих в романтических отношениях.",round(data[data['internet']=='yes']['G3'].mean()-data[data['internet']=='no']['G3'].mean(),2))
data[data['internet']=='yes']
data[data['internet']=='no']
# Out:
# разность между средними итоговыми оценками студентов, состоящих и не состоящих в романтических отношениях. 1.21
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 17      GP   F   16       U     GT3       T     3     3     other     other
# 35      GP   F   15       U     GT3       T     2     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 384     MS   M   18       R     GT3       T     4     2     other     other
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# ...
